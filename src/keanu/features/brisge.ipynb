# %%
import szxxx.common.hist_data as hd 
import keanu.config as conf
import shot.dataphora as dp

# %%
DATA = hd.set_hist_data(conf)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 DATA = hd.set_hist_data(conf)
#
# File ~\Documents\workspaces\szx81\szxxx\src\szxxx\common\hist_data.py:197, in set_hist_data(config, force_save, verbose)
#     195     HIST_DATA = HistData(config=config)
#     196     DICT_DATA = HIST_DATA.data
# --> 197     save_data(DICT_DATA, label, data_store=data_store)
#     199 DATA = list(DICT_DATA.values())
#     200 TIMESTAMP_INDEX = {k: v[-1] for k, v in DICT_DATA.items()}
#
# File ~\Documents\workspaces\szx81\szxxx\src\szxxx\common\hist_data.py:16, in save_data(data, label, data_store)
#      15 def save_data(data, label, data_store):
# ---> 16     with open(data_store, 'wb') as f:
#      17         pickle.dump((data, label), f)
#      18     print(f'Saved to file {data_store}')
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\stefa\\Documents\\workspaces\\szx81\\data_stores\\keanu\\EURUSD\\data_store'

# %%
len(DATA)
# Out:
# 0

# %%
dataphora = dp.Bridge(
    timeshots=DATA, 
    monotonic_duration=10, 
    vertical_range={dp.Direction.BWD: 150, dp.Direction.FWD: 100},
    snapshot_size={dp.Direction.BWD: 12, dp.Direction.FWD: 10}, 
    adversity=0.5, sltp=90)
# Out:
# Received 0 timeshots
# ASC decision points: 0 found
# DSC decision points: 0 found
